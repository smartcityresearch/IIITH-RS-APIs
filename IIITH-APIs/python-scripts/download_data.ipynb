# %%
import requests as requests

pip install requests
# Out:
# ...
#   Using cached urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
# ...
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# ...
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# WARNING: You are using pip version 21.1.2; however, version 22.0.3 is available.
# You should consider upgrading via the 'd:\iiith\github\code\mlvenv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
"""
change the start time and end time and node name as per needs. Change the filename as per needs in the last cell.
The request gets you 2000 records as of now. Run multiple times to get the required period of time.
"""
url = "https://iudx-rs-onem2m.iiit.ac.in/channels/SL-VN03-00/feeds.json/?start=2022-02-22T00:00:00Z&end=2023-02-28T20:20:01Z&api_key=replaceapikeyhere"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"channel": {"id": "SL-VN03-00", "description": "Growatt 80KT3LV Inverters (80 kW), id=1.0", "field1": "Eac_today", "field2": "Eac_total", "field3": "ActivePower", "field4": "Voltage_RS", "field5": "Voltage_ST", "field6": "Voltage_TR", "field7": "Frequency", "field8": "Power Factor", "field9": "Voltage1", "field10": "Current1", "field11": "Power1", "field12": "Voltage2", "field13": "Current2", "field14": "Power2", "field15": "Voltage3", "field16": "Current3", "field17": "Power3", "field18": "PV1Voltage", "field19": "PV1Current", "field20": "PV1Power", "field21": "PV2Voltage", "field22": "PV2Current", "field23": "PV2Power", "field24": "PV3Voltage", "field25": "PV3Current", "field26": "PV3Power", "field27": "PV4Voltage", "field28": "PV4Current", "field29": "PV4Power", "field30": "PV5Voltage", "field31": "PV5Current", "field32": "PV5Power", "field33": "PV6Voltage", "field34": "PV6Current", "field35": "PV6Power", "field36": "VersionInfo"}, "feeds": [{"created_at": "2022-03-07T10:49:00+05
# ...

# %%
var=response.text

# %%
var=eval(var)

# %%
len(var)
# Out:
# 2

# %%
var['feeds']
# Out:
# [{'created_at': '2022-03-07T10:49:00+05:30',
#   'field1': 116.6,
#   'field2': 129472.8,
#   'field3': 54150.3,
#   'field4': 415.3,
#   'field5': 412.8,
#   'field6': 413.3,
#   'field7': 49.97,
#   'field8': 2.0,
#   'field9': 241.1,
#   'field10': 75.5,
#   'field11': 18203.0,
#   'field12': 239.6,
#   'field13': 75.6,
#   'field14': 18113.7,
#   'field15': 235.6,
#   'field16': 75.8,
#   'field17': 17858.4,
#   'field18': 740.4,
#   'field19': 12.6,
#   'field20': 9268.7,
#   'field21': 730.3,
#   'field22': 13.1,
#   'field23': 9566.9,
#   'field24': 720.2,
#   'field25': 12.8,
#   'field26': 9218.5,
#   'field27': 721.1,
#   'field28': 6.0,
#   'field29': 4326.6,
#   'field30': 728.4,
#   'field31': 12.6,
#   'field32': 9177.8,
#   'field33': 735.4,
#   'field34': 6.6,
#   'field35': 4808.7,
#   'field36': 'V2.0.1'},
#  {'created_at': '2022-03-07T10:48:00+05:30',
#   'field1': 115.7,
#   'field2': 129471.9,
#   'field3': 54291.1,
#   'field4': 415.4,
#   'field5': 411.8,
# ...

# %%
len(var['feeds'])
# Out:
# 2000

# %%
var['feeds'][6]
# Out:
# {'created_at': '2022-03-07T10:42:00+05:30',
#  'field1': 110.8,
#  'field2': 129467.0,
#  'field3': 53752.2,
#  'field4': 414.5,
#  'field5': 410.8,
#  'field6': 412.3,
#  'field7': 49.99,
#  'field8': 2.0,
#  'field9': 240.8,
#  'field10': 75.3,
#  'field11': 18132.2,
#  'field12': 238.5,
#  'field13': 75.2,
#  'field14': 17935.2,
#  'field15': 235.3,
#  'field16': 75.3,
#  'field17': 17718.0,
#  'field18': 741.4,
#  'field19': 12.4,
#  'field20': 9193.3,
#  'field21': 735.1,
#  'field22': 13.0,
#  'field23': 9556.3,
#  'field24': 725.9,
#  'field25': 12.6,
#  'field26': 9146.3,
#  'field27': 718.7,
#  'field28': 5.9,
#  'field29': 4240.3,
#  'field30': 724.5,
#  'field31': 12.5,
#  'field32': 9056.2,
#  'field33': 736.1,
#  'field34': 6.6,
#  'field35': 4858.2,
#  'field36': 'V2.0.1'}

# %%
import pandas as pd

# %%
df = pd.DataFrame(var['feeds'])

# %%
df
# Out:
#                      created_at field1    field2   field3 field4 field5  \
# 0     2022-03-07T10:49:00+05:30  116.6  129472.8  54150.3  415.3  412.8
# 1     2022-03-07T10:48:00+05:30  115.7  129471.9  54291.1  415.4  411.8
# 2     2022-03-07T10:47:00+05:30  114.7  129470.8  54200.3  415.8  412.3
# 3     2022-03-07T10:46:00+05:30  113.7  129469.8  54044.9  415.5  412.2
# 4     2022-03-07T10:45:00+05:30  112.8  129468.9  53753.5  414.8  411.5
# ...                         ...    ...       ...      ...    ...    ...
# 1995  2022-03-04T12:55:00+05:30  225.7  128357.9  56371.3  424.6  421.8
# 1996  2022-03-04T12:54:00+05:30  224.7  128356.9  56423.8  424.0  420.9
# 1997  2022-03-04T12:53:00+05:30  223.7  128355.9  56592.9  424.3  420.6
# 1998  2022-03-04T12:52:00+05:30  222.7  128354.9  56700.5  424.1  420.8
# 1999  2022-03-04T12:51:00+05:30  221.6  128353.9  55809.5  424.1  420.5
#
#      field6 field7 field8 field9  ... field27 field28 field29 field30 field31  \
# ...

# %%
df.columns=list(var['channel'].values())[1:]

# %%
df.to_excel('filename.xlsx')

# %%
df
